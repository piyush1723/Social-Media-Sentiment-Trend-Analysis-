# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

df = pd.read_csv("../data/processed/clean_twitter.csv")

df.head()
df.shape
# Out:
# (31930, 4)

# %% [markdown]
# Features And Target

# %%
X=df['clean_tweet']
y=df['label']

# %% [markdown]
# Creating Vectorizer

# %%
tfidf = TfidfVectorizer(max_features=5000)
X_tfidf=tfidf.fit_transform(X)

# %%
X_tfidf.shape
len(tfidf.vocabulary_)
print(X_tfidf.shape)
# Out:
# (31930, 5000)

# %%
feature_names = tfidf.get_feature_names_out()

print(feature_names[:20])
# Out:
# ['aamp' 'aap' 'ab' 'abandon' 'abc' 'abil' 'abl' 'ableism' 'abrahamhick'
#  'absolut' 'abt' 'abund' 'abus' 'academi' 'acc' 'accent' 'accept' 'access'
#  'accessori' 'accid']

# %% [markdown]
# ## Conclusion
#
# - Applied TF-IDF Vectorization
# - Converted text into numerical features
# - Generated 5000 TF-IDF features
# - Dataset is now ready for machine learning model training
